# %% [markdown]
# # Pandas Week 8 - Joshua Lewi (2473018)

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
# Out:
# 1.0.3

# %%
d = {'col_1':[1, 2, 3, 4, 5],
     'col_2':[10, 20, 30, 40, 50]}
df = pd.DataFrame(d)
df
# Out:
#    col_1  col_2
# 0      1     10
# 1      2     20
# 2      3     30
# 3      4     40
# 4      5     50

# %% [markdown]
# Random sampling with/without replacement

# %%
df.sample(n=4, replace=False, random_state=0)
# Out:
#    col_1  col_2
# 2      3     30
# 0      1     10
# 1      2     20
# 3      4     40

# %%
df.sample(n=4, replace=True, random_state=0)
# Out:
#    col_1  col_2
# 4      5     50
# 0      1     10
# 3      4     40
# 3      4     40

# %% [markdown]
# ### 30. Akses nilai variable dalam fungsi query

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns=cols)

df
# Out:
#     A   B   C   D   E
# 0  13   1   8  10  18
# 1   6   6  14  19   4
# 2  12  18  17   7  15
# 3   1  16   1  10   9
# 4  17   3   9  10   8

# %% [markdown]
# Mengakses nilai variable pada query()

# %%
df.query('A > 10')
# Out:
#     A   B   C   D   E
# 0  13   1   8  10  18
# 2  12  18  17   7  15
# 4  17   3   9  10   8

# %%
rerata = df['A'].mean()
rerata
# Out:
# 9.8

# %%
df.query('A > @rerata')
# Out:
#     A   B   C   D   E
# 0  13   1   8  10  18
# 2  12  18  17   7  15
# 4  17   3   9  10   8

# %% [markdown]
# ### 31. Tipe Data Ordinal

# %%
d = {'pelanggan':[11, 12, 13, 14],
     'kepuasan':['baik', 'cukup', 'buruk', 'cukup']}

df = pd.DataFrame(d)
df
# Out:
#    pelanggan kepuasan
# 0         11     baik
# 1         12    cukup
# 2         13    buruk
# 3         14    cukup

# %% [markdown]
# Tipe data ordinal di Pandas

# %%
# Harus diajarin dulu
from pandas.api.types import CategoricalDtype

tingkat_kepuasan = CategoricalDtype(['buruk', 'cukup', 'baik', 'sangat baik'],
                                    ordered=True)

df['kepuasan'] = df['kepuasan'].astype(tingkat_kepuasan)
df
# Out:
#    pelanggan kepuasan
# 0         11     baik
# 1         12    cukup
# 2         13    buruk
# 3         14    cukup

# %%
df = df.sort_values('kepuasan', ascending=True)
df
# Out:
#    pelanggan kepuasan
# 2         13    buruk
# 1         12    cukup
# 3         14    cukup
# 0         11     baik

# %%
df[df['kepuasan'] >= 'cukup'] #Filtering
# Out:
#    pelanggan kepuasan
# 1         12    cukup
# 3         14    cukup
# 0         11     baik

# %% [markdown]
# ### 32. Plotting dari Pandas Data Frame (Visualisasi Data pakai Pandas)

# %%
n_rows = 40
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns=cols)
df.head()
# Out:
#     A   B   C   D   E
# 0   4   7   5  11  16
# 1  19  10  19   1   3
# 2  18   9  14  15  12
# 3  15  18   9  12  13
# 4  17   9  15   3  16

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   4   7   5  11  16
# 1  19  10  19   1   3
# 2  18   9  14  15  12
# 3  15  18   9  12  13
# 4  17   9  15   3  16

# %%
df.plot(kind='line')

# %%
df[['A', 'B']].plot(kind='line')

# %% [markdown]
# Bar Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   4   7   5  11  16
# 1  19  10  19   1   3
# 2  18   9  14  15  12
# 3  15  18   9  12  13
# 4  17   9  15   3  16

# %%
df.plot(kind='bar')

# %%
df[['A', 'B']].plot(kind='bar')

# %%
df[['A', 'B']].head().plot(kind='bar')

# %%
df[['A', 'B']].head().plot(kind='barh')

# %% [markdown]
# Area Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   4   7   5  11  16
# 1  19  10  19   1   3
# 2  18   9  14  15  12
# 3  15  18   9  12  13
# 4  17   9  15   3  16

# %%
df.plot(kind='area')

# %%
df[['A', 'B']].plot(kind='area')

# %% [markdown]
# Box Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   4   7   5  11  16
# 1  19  10  19   1   3
# 2  18   9  14  15  12
# 3  15  18   9  12  13
# 4  17   9  15   3  16

# %%
df.plot(kind='box')

# %% [markdown]
# Histogram

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   4   7   5  11  16
# 1  19  10  19   1   3
# 2  18   9  14  15  12
# 3  15  18   9  12  13
# 4  17   9  15   3  16

# %%
df.plot(kind='hist')

# %%
df[['A', 'B']].plot(kind='hist')

# %% [markdown]
# Kernel Density Estimation (KDE)

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   4   7   5  11  16
# 1  19  10  19   1   3
# 2  18   9  14  15  12
# 3  15  18   9  12  13
# 4  17   9  15   3  16

# %%
df.plot(kind='kde')

# %% [markdown]
# Scatter Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0   4   7   5  11  16
# 1  19  10  19   1   3
# 2  18   9  14  15  12
# 3  15  18   9  12  13
# 4  17   9  15   3  16

# %%
df.plot(x='A', y='B', kind='scatter')
